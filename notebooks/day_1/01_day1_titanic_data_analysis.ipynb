# %% [markdown]
# # Day 1 Workbook: Titanic Data Analysis with Pandas
#
# ![RMS Titanic](https://raw.githubusercontent.com/ValRCS/RTU_Python_Data_Analysis_Visualization_May_2026/main/img/titanic.jpg)
#
# Image file in this repository: `img/titanic.jpg`
#
# The RMS Titanic was a British passenger ship that sank in April 1912 after striking an iceberg during its first voyage. The passenger dataset used in this workbook contains one row per passenger and columns such as passenger class, sex, age, fare, cabin, embarkation port, and whether the passenger survived.
#
# The Titanic dataset is widely used for beginner data-analysis practice because it is small enough to understand, but realistic enough to include useful analytical questions, categories, numeric values, missing data, filtering, grouping, and careful interpretation. We will use it to learn practical Pandas workflows, not to build a prediction model.
#
# The goal is not to memorize syntax. The goal is to learn a repeatable workflow:
#
# 1. Load a table.
# 2. Inspect rows, columns, data types, and missing values.
# 3. Filter and sort the data.
# 4. Make simple cleaning decisions.
# 5. Summarize results and write short conclusions.
#
# In Excel terms, we will work with a table, inspect columns, filter rows, sort values, create Pivot Table style summaries, and document the steps so the analysis can be repeated.

# %% [markdown]
# ## Learning Outcomes
#
# By the end of this workbook, you should be able to:
#
# - write simple Markdown text cells for headings, lists, notes, and conclusions
# - run simple Python code cells and understand why cell order matters
# - load a CSV file into a Pandas DataFrame
# - inspect the size, columns, data types, and missing values in a dataset
# - select columns, filter rows, sort rows, and count categories
# - make beginner-friendly cleaning decisions for missing values
# - group data and create summary tables
# - write short analytical conclusions from visible outputs

# %% [markdown]
# ## How to Use This Workbook
#
# This workbook starts with notebook basics before it starts the Titanic analysis.
#
# First, we practice Markdown text cells so you can document your work. Then we run a few small Python code cells so the notebook interface feels familiar. After that, we import the data-analysis libraries and load the Titanic dataset.
#
# Run the cells from top to bottom.
#
# Most code cells show a table, summary, count, or chart. After running a cell, pause and inspect the output before moving on.
#
# Some sections include guided practice and mini tasks. These are meant to be edited during class. The provided code already runs, so the notebook can still be executed with **Run all** in Google Colab.

# %% [markdown]
# ## Warm-Up 1: Markdown Text Cells
#
# ### Goal
#
# Before working with data, we will practice writing notebook text.
#
# Markdown cells are the explanation layer of a notebook. They help you document what you are doing, why you are doing it, and what the output means.
#
# In this course, Markdown is just as important as code because the final result should be a readable analysis, not a loose collection of commands.

# %% [markdown]
# ### What Markdown Is
#
# Markdown is a simple way to format text using plain characters.
#
# In Google Colab, a text cell can contain headings, paragraphs, lists, bold text, links, and small tables.
#
# Useful habit: write a short note before important code cells and a short interpretation after important outputs.

# %% [markdown]
# ### Headings
#
# Headings organize a notebook into readable sections.
#
# Markdown syntax:
#
# ```markdown
# # Main title
# ## Large section
# ### Smaller section
# #### Small note
# ```
#
# Use headings to make your analysis easy to scan later.

# %% [markdown]
# ### Paragraphs and Line Breaks
#
# Normal text becomes a paragraph.
#
# Leave a blank line between paragraphs:
#
# ```markdown
# This is one paragraph.
#
# This is another paragraph.
# ```
#
# Keep notebook paragraphs short. One idea per paragraph is easier to read during class.

# %% [markdown]
# ### Bold, Italic, and Inline Code
#
# Markdown syntax:
#
# ```markdown
# **important result**
# *optional note*
# `column_name`
# ```
#
# Use inline code formatting for column names, variable names, and short pieces of code such as `titanic.head()`.

# %% [markdown]
# ### Lists
#
# Bulleted lists are useful for observations:
#
# ```markdown
# - first observation
# - second observation
# - third observation
# ```
#
# Numbered lists are useful for steps:
#
# ```markdown
# 1. Load the data.
# 2. Inspect the columns.
# 3. Write a conclusion.
# ```

# %% [markdown]
# ### Links
#
# Markdown syntax:
#
# ```markdown
# [Google Colab](https://colab.research.google.com/)
# ```
#
# Links are useful when you want to document a dataset source or reference material.

# %% [markdown]
# Saite uz [RTU](https://www.rtu.lv/)
#
# Bildes piemērs
# ![RTU logo](https://www.rtu.lv/images/logo_lv.svg?v=1.1)
#
# Ja vajag izmēru mainīt bildei tad gan jālieto HTML `<img>` birka
#
# Markdown principā var likt jebkādu HTML, bet atkal HTML ir sarežģītāks

# %% [markdown]
# ### Simple Tables
#
# Markdown syntax:
#
# ```markdown
# | Question | Output to inspect |
# | --- | --- |
# | How many rows? | `shape` |
# | Which columns? | `columns` |
# | Any blanks? | `isna().sum()` |
# ```
#
# Tables are useful for short summaries, but data tables should usually come from code.

# %% [markdown]
# ### Guided Practice: Create a Text Cell
#
# In Colab, insert a text cell and write a short note using:
#
# - one heading
# - one sentence
# - one bullet list
# - one inline code example, such as `head()`
#
# Suggested text:
#
# ```markdown
# ### My First Notebook Note
#
# Today I am learning how to document a data analysis.
#
# - load data
# - inspect columns
# - write conclusions
#
# The first Pandas command I will use is `head()`.
# ```

# %% [markdown]
# ### Check Your Understanding
#
# Answer in plain language:
#
# - Which symbol creates a heading?
# - Why are short Markdown notes useful in an analysis notebook?
# - When should you use inline code formatting?
# - How is a notebook different from an Excel worksheet?

# %% [markdown]
# ### Common Markdown Mistakes
#
# - Forgetting a blank line between paragraphs.
# - Making every sentence a heading.
# - Writing long notes that nobody will reread.
# - Forgetting to interpret outputs after running code.
#
# Markdown does not need to be fancy. It needs to make the analysis understandable.

# %% [markdown]
# ### Independent Mini Task
#
# Add a text cell that answers these questions:
#
# 1. What dataset are we going to analyze today?
# 2. What is one question we might ask about passengers?
# 3. What kind of output would help answer that question?
#
# Keep the answer short. This should take about five minutes.

# %% [markdown]
# ## Warm-Up 2: Code Cell Basics and Hello Python
#
# ### Goal
#
# Now we will run a few simple Python code cells before loading any data.
#
# Code cells are where calculations happen. Text cells explain the work. A useful notebook uses both.

# %% [markdown]
# ### Instructor Demonstration
#
# The first code cell prints a short message.
#
# Click the cell and run it. In Colab, you can use the play button or press **Shift + Enter**.

# %%
print("Hello, Python notebook no Valda RTU!")
# Out:
# Hello, Python notebook no Valda RTU!

# %% [markdown]
# A code cell can also calculate a value. If the last line of a cell is an expression, Colab displays the result.

# %%
2 + (3 * 10) # izmantojam Colab kā kalkulātoru
# Out:
# 32

# %% [markdown]
# Text values must go inside quotation marks.

# %%
"This is a text value from a code cell." # atakal neko neglabājam
# Out:
# 'This is a text value from a code cell.'

# %% [markdown]
# A variable stores a value so we can reuse it later. This is similar to giving a name to an intermediate result.

# %%
course_name = "Python Data Analysis"
course_name
# Out:
# 'Python Data Analysis'

# %% [markdown]
# Code runs in order. The next cell uses the variable created in the previous cell.

# %%
print("Today we are learning:", course_name)
# Out:
# Today we are learning: Python Data Analysis

# %% [markdown]
# Comments start with `#`. Python ignores comments, but humans can read them.

# %%
# This is a comment.
# It explains the next line of code.
10 * 4
# Out:
# 40

# %% [markdown]
# ### Guided Practice
#
# Change the message below and run the cell again.

# %%
print("I can run a code cell in Colab.")
# Out:
# I can run a code cell in Colab.

# %% [markdown]
# ### Check Your Understanding
#
# Answer in plain language:
#
# - What is the difference between a text cell and a code cell?
# - What does `print()` do?
# - Why does code cell order matter?
# - What does a comment do?

# %% [markdown]
# ### Common Code Cell Mistakes
#
# - Running cells out of order.
# - Forgetting quotation marks around text.
# - Editing a cell but forgetting to run it again.
# - Thinking an error means failure. Errors are normal feedback while learning.
#
# If the notebook feels confused, use **Runtime > Restart session and run all** in Colab.

# %% [markdown]
# ### Independent Mini Task
#
# Create a small code cell that:
#
# 1. stores your first name in a variable
# 2. prints a greeting
#
# Example:
#
# ```python
# first_name = "Anna"
# print("Hello", first_name)
# ```
#
# After this warm-up, we are ready to start the real data-analysis setup.

# %%
# KODS ŠEIT

# %% [markdown]
# ## Setup for Data Analysis
#
# Now that we have practiced text cells and basic code cells, we can prepare the libraries for data analysis.
#
# We use three standard libraries for this course:
#
# - `pandas` for working with tables
# - `matplotlib.pyplot` for basic chart display
# - `seaborn` for readable statistical charts
#
# Google Colab already includes these libraries, so no installation cell is needed.

# %%
import pandas as pd # datu analīzei
import matplotlib.pyplot as plt # grafiskā biblioteka
import seaborn as sns # papildu grafiskā
from pathlib import Path # un darbam ar failiem

sns.set_theme(style="whitegrid") # krāsu gammu papildu bibliotekai

# %% [markdown]
# ## Load the Titanic Dataset
#
# This is where the data-analysis workflow begins.
#
# The loading cell first tries the local repository path. If the file is not available locally, it loads the CSV from GitHub.
#
# Because this notebook is inside `notebooks/day_1/`, the local path goes up two folders to reach `data/titanic.csv`.

# %%
TITANIC_URL = "https://raw.githubusercontent.com/ValRCS/RTU_Python_Data_Analysis_Visualization_May_2026/main/data/titanic.csv"

local_path = Path("../../data/titanic.csv")

# mēs vispirms pārbaudam vai mums jau gadijumā nav ši datu kopa - lokali varētu jau būt
if local_path.exists():
    titanic = pd.read_csv(local_path) # ielādētu no lokālā faila
else:
    titanic = pd.read_csv(TITANIC_URL) #šeit no tīmekļa adreses

titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Subchapter 1: Loading and First Look at Titanic Data
#
# ### Goal
#
# Load the Titanic data and confirm that it looks like a usable passenger table.
#
# At this point, we are moving from notebook warm-up into the practical data-analysis workflow.

# %% [markdown]
# ### Instructor Demonstration
#
# The first inspection step is usually to look at the first few rows. This is similar to opening an Excel sheet and checking whether the table looks as expected.

# %%
titanic.head(10) # so 10 means show first 10 rows
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# The column names are visible at the top. Some names are easy to understand, such as `Name`, `Sex`, `Age`, and `Fare`. Others may need explanation, such as `Pclass` and `Embarked`.

# %%
row_count, column_count = titanic.shape # from shape we can extract individual values
print("Row count", row_count)
print("Column count", column_count)
row_count, column_count
# Out:
# Row count 891
# Column count 12
# (891, 12)

# %% [markdown]
# ### Guided Practice
#
# Change the number inside `head()` to show more or fewer rows. The example below shows 10 rows.

# %%
titanic.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# ### Check Your Understanding
#
# Before running the next cell, predict:
#
# - Will it show rows from the beginning or the end of the table?
# - How many rows will it show?

# %%
titanic.tail(3) # tātad tail means last 3 rows here (default is 5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# for large data frames / tables you might want to use sample to get a better idea of what you have
titanic.sample(5) # this will change each time you run it
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 510          511         1       3                   Daly, Mr. Eugene Patrick
# 430          431         1       1  Bjornstrom-Steffansson, Mr. Mauritz Hakan
# 6              7         0       1                    McCarthy, Mr. Timothy J
# 504          505         1       1                      Maioni, Miss. Roberta
# 48            49         0       3                        Samaan, Mr. Youssef
#
#         Sex   Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 510    male  29.0      0      0  382651   7.7500   NaN        Q
# 430    male  28.0      0      0  110564  26.5500   C52        S
# 6      male  54.0      0      0   17463  51.8625   E46        S
# 504  female  16.0      0      0  110152  86.5000   B79        S
# 48     male   NaN      2      0    2662  21.6792   NaN        C

# %%
# if i want a concrete sample I can use specific seed to get specific sample
# most random numbers in computer world are actually pseudo-random numbers, they get some random seed from mouse/clock/some other events and then use mathematical formula
titanic.sample(5, random_state=2026) # this will always give same sample
# Out:
#      PassengerId  Survived  Pclass  \
# 747          748         1       2
# 734          735         0       2
# 871          872         1       1
# 242          243         0       2
# 527          528         0       1
#
#                                                  Name     Sex   Age  SibSp  \
# 747                             Sinkkonen, Miss. Anna  female  30.0      0
# 734                      Troupiansky, Mr. Moses Aaron    male  23.0      0
# 871  Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 242                   Coleridge, Mr. Reginald Charles    male  29.0      0
# 527                                Farthing, Mr. John    male   NaN      0
#
#      Parch       Ticket      Fare Cabin Embarked
# 747      0       250648   13.0000   NaN        S
# 734      0       233639   13.0000   NaN        S
# 871      1        11751   52.5542   D35        S
# 242      0  W./C. 14263   10.5000   NaN        S
# 527      0     PC 17483  221.7792   C95        S

# %% [markdown]
# ### Independent Mini Task
#
# Use one of the preview commands and write down one thing you notice about the dataset.
#
# Possible observations:
#
# - some passengers have missing cabin information
# - fare values are numeric
# - passenger class is coded as 1, 2, or 3

# %%
titanic.head(7)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# ### Interpretation
#
# We have loaded the data and confirmed that it looks like a passenger table. Next we need to understand what each column contains before we filter or summarize anything.

# %% [markdown]
# ## Subchapter 2: Understanding Rows, Columns, Data Types, and Missing Values
#
# ### Goal
#
# Learn how to inspect a dataset before analyzing it.
#
# In Excel, you might check headers, blanks, and whether columns contain text, numbers, or dates. In Pandas, we use inspection commands for the same purpose.

# %% [markdown]
# ### Instructor Demonstration
#
# First, list the column names.

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# `info()` gives a compact overview of rows, columns, data types, and non-missing values.

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# Numeric columns can be summarized with `describe()`. This gives counts, averages, minimums, maximums, and quartiles.
#
# For beginners, focus first on count, mean, min, and max.

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# We can also inspect selected categorical columns. Categorical columns contain labels or groups, such as `Sex`, `Pclass`, and `Embarked`.

# %%
titanic[["Sex", "Pclass", "Embarked", "Survived"]].describe(include="all")
# note the use of double [["columnA", "columnB"]]
# if I use (include="all") then also nonnumeric columns will be described
# Out:
#          Sex      Pclass Embarked    Survived
# count    891  891.000000      889  891.000000
# unique     2         NaN        3         NaN
# top     male         NaN        S         NaN
# freq     577         NaN      644         NaN
# mean     NaN    2.308642      NaN    0.383838
# std      NaN    0.836071      NaN    0.486592
# min      NaN    1.000000      NaN    0.000000
# 25%      NaN    2.000000      NaN    0.000000
# 50%      NaN    3.000000      NaN    0.000000
# 75%      NaN    3.000000      NaN    1.000000
# max      NaN    3.000000      NaN    1.000000

# %% [markdown]
# Missing values are blank or unavailable values. Before analyzing, we should know where they are.

# %%
# I create a new Dataframe by creating a dictionary
# so keys will be column names
# and then values become cells
missing_report = pd.DataFrame({
    "missing_rows": titanic.isna().sum(),
    "missing_percent": (titanic.isna().mean() * 100).round(2) # so round(2) means round 2 digits after comma and so on
})

missing_report.sort_values("missing_rows", ascending=False)
# Out:
#              missing_rows  missing_percent
# Cabin                 687            77.10
# Age                   177            19.87
# Embarked                2             0.22
# PassengerId             0             0.00
# Name                    0             0.00
# Pclass                  0             0.00
# Survived                0             0.00
# Sex                     0             0.00
# Parch                   0             0.00
# SibSp                   0             0.00
# Fare                    0             0.00
# Ticket                  0             0.00

# %% [markdown]
# The main missing value pattern is:
#
# - `Cabin` is mostly missing.
# - `Age` has many missing values.
# - `Embarked` has only a few missing values.
#
# This matters because cleaning choices affect later analysis.

# %% [markdown]
# ### Guided Practice
#
# Inspect a smaller set of useful columns. This is often easier than looking at the whole table.

# %%
titanic[["Age", "Fare", "Pclass", "Survived"]].describe()
# Out:
#               Age        Fare      Pclass    Survived
# count  714.000000  891.000000  891.000000  891.000000
# mean    29.699118   32.204208    2.308642    0.383838
# std     14.526497   49.693429    0.836071    0.486592
# min      0.420000    0.000000    1.000000    0.000000
# 25%     20.125000    7.910400    2.000000    0.000000
# 50%     28.000000   14.454200    3.000000    0.000000
# 75%     38.000000   31.000000    3.000000    1.000000
# max     80.000000  512.329200    3.000000    1.000000

# %% [markdown]
# ### Check Your Understanding
#
# Answer in plain language:
#
# - Which column has the most missing values?
# - Why might `Cabin` be risky as a main analysis column?
# - Which columns look numeric?
# - Which columns look categorical?

# %% [markdown]
# ### Common Mistake
#
# A common beginner mistake is to begin filtering or charting before checking missing values. The result might still run, but the interpretation may be weak.
#
# Good habit: inspect first, analyze second.

# %% [markdown]
# ### Independent Mini Task
#
# Choose three columns and decide whether each one is numeric or categorical.
#
# The code below gives a small preview of three categorical columns.

# %%
titanic[["Sex", "Pclass", "Embarked"]].head(10)
# Out:
#       Sex  Pclass Embarked
# 0    male       3        S
# 1  female       1        C
# 2  female       3        S
# 3  female       1        S
# 4    male       3        S
# 5    male       3        Q
# 6    male       1        S
# 7    male       3        S
# 8  female       3        S
# 9  female       2        C

# %%
# let's take value counts for "Sex" column
titanic["Sex"].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
# now Pclass
titanic["Pclass"].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
# embarked
titanic["Embarked"].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
# at this stage I'd like to get fuller descriptions
# for example what are S, C and Q in Embarked?
# We have no clue directly
# but we have Kaggle and other places
# https://www.kaggle.com/competitions/titanic/data
# so C = Cherbourg, Q = Queenstown, S = Southampton
# let's make a function and then apply
def embarked_description(embarked):
    if embarked == "C":
        return "Cherbourg"
    elif embarked == "Q":
        return "Queenstown"
    elif embarked == "S":
        return "Southampton"
    else:
        return "Unknown" # if we get something else, even though here it is not possible

# let's apply by making embarked_full column
titanic["embarked_city"] = titanic["Embarked"].apply(embarked_description)
# show these two columns the first 10 rows
titanic[["Embarked", "embarked_city"]].head(10)
# Out:
#   Embarked embarked_city
# 0        S   Southampton
# 1        C     Cherbourg
# 2        S   Southampton
# 3        S   Southampton
# 4        S   Southampton
# 5        Q    Queenstown
# 6        S   Southampton
# 7        S   Southampton
# 8        S   Southampton
# 9        C     Cherbourg

# %% [markdown]
# ### Interpretation
#
# We now understand the table structure, basic column types, and missing value pattern. This gives us enough context to start selecting, filtering, and sorting rows.

# %% [markdown]
# ## Subchapter 3: Selecting, Filtering, Sorting, and Counting
#
# ### Goal
#
# Learn how to focus on selected columns and selected rows.
#
# This is similar to filtering and sorting an Excel table, but the steps are written down so they can be repeated.

# %% [markdown]
# ### Instructor Demonstration
#
# Select one column by writing its name in square brackets.

# %%
titanic["Age"].head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64

# %% [markdown]
# Select several columns by using a list of column names.

# %%
titanic[["Name", "Age", "Sex"]].head() # again note the double [[]]
# Out:
#                                                 Name   Age     Sex
# 0                            Braund, Mr. Owen Harris  22.0    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female
# 2                             Heikkinen, Miss. Laina  26.0  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female
# 4                           Allen, Mr. William Henry  35.0    male

# %% [markdown]
# Filter rows by writing a condition. The next example keeps passengers whose age is at least 18.

# %%
adult_passengers = titanic[titanic["Age"] >= 18]
# I could save the table here
adult_passengers.to_csv("adult_passengers.csv")
# i could also download it from Google Colab
# from google.colab import files
# files.download("adult_passengers.csv")

adult_passengers[["Name", "Age", "Sex", "Pclass"]].head()
# Out:
#                                                 Name   Age     Sex  Pclass
# 0                            Braund, Mr. Owen Harris  22.0    male       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female       1
# 2                             Heikkinen, Miss. Laina  26.0  female       3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female       1
# 4                           Allen, Mr. William Henry  35.0    male       3

# %%
# how many adults do we have?
# shape
print("Adult passengers:", adult_passengers.shape[0])
# shape has two values rowcount and column count we need the first one with 0 index
print("Total passengers:", titanic.shape[0])
# percentage
print("Adult passengers percentage:", round(adult_passengers.shape[0] / titanic.shape[0] * 100, 2), "%")
# Out:
# Adult passengers: 601
# Total passengers: 891
# Adult passengers percentage: 67.45 %

# %% [markdown]
# We can filter using other numeric columns too. This example keeps rows where the fare was greater than 50.

# %%
higher_fare_passengers = titanic[titanic["Fare"] > 50]

higher_fare_passengers[["Name", "Fare", "Pclass"]].head()
# Out:
#                                                  Name      Fare  Pclass
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...   71.2833       1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)   53.1000       1
# 6                             McCarthy, Mr. Timothy J   51.8625       1
# 27                     Fortune, Mr. Charles Alexander  263.0000       1
# 31     Spencer, Mrs. William Augustus (Marie Eugenie)  146.5208       1

# %% [markdown]
# For text or category columns, use `==` to check for an exact match.

# %%
first_class_passengers = titanic[titanic["Pclass"] == 1]

first_class_passengers[["Name", "Pclass", "Fare"]].head()
# Out:
#                                                  Name  Pclass     Fare
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...       1  71.2833
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  53.1000
# 6                             McCarthy, Mr. Timothy J       1  51.8625
# 11                           Bonnell, Miss. Elizabeth       1  26.5500
# 23                       Sloper, Mr. William Thompson       1  35.5000

# %% [markdown]
# Combine conditions with care. Each condition goes inside parentheses, and `&` means "and".

# %%
# we can use & for AND
# and | for OR
female_first_class = titanic[
    (titanic["Sex"] == "female") &
    (titanic["Pclass"] == 1)
]

female_first_class[["Name", "Sex", "Pclass", "Survived"]].head()
# Out:
#                                                  Name     Sex  Pclass  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female       1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female       1
# 11                           Bonnell, Miss. Elizabeth  female       1
# 31     Spencer, Mrs. William Augustus (Marie Eugenie)  female       1
# 52           Harper, Mrs. Henry Sleeper (Myna Haxtun)  female       1
#
#     Survived
# 1          1
# 3          1
# 11         1
# 31         1
# 52         1

# %% [markdown]
# Sorting is similar to sorting a table column in Excel.

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'embarked_city'],
#       dtype='object')

# %%
titanic.sort_values("Fare", ascending=False)[["Name", "Pclass", "Fare","Survived"]].head(10)
# Out:
#                                                 Name  Pclass      Fare  \
# 679               Cardeza, Mr. Thomas Drake Martinez       1  512.3292
# 258                                 Ward, Miss. Anna       1  512.3292
# 737                           Lesurer, Mr. Gustave J       1  512.3292
# 88                        Fortune, Miss. Mabel Helen       1  263.0000
# 438                                Fortune, Mr. Mark       1  263.0000
# 341                   Fortune, Miss. Alice Elizabeth       1  263.0000
# 27                    Fortune, Mr. Charles Alexander       1  263.0000
# 742            Ryerson, Miss. Susan Parker "Suzette"       1  262.3750
# 311                       Ryerson, Miss. Emily Borie       1  262.3750
# 299  Baxter, Mrs. James (Helene DeLaudeniere Chaput)       1  247.5208
#
#      Survived
# 679         1
# 258         1
# 737         1
# 88          1
# 438         0
# 341         1
# 27          0
# 742         1
# 311         1
# 299         1

# %% [markdown]
# `value_counts()` counts how often each category appears.

# %%
titanic["Pclass"].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
titanic["Embarked"].value_counts(dropna=False)
# Out:
# Embarked
# S      644
# C      168
# Q       77
# NaN      2
# Name: count, dtype: int64

# %% [markdown]
# ### Guided Practice
#
# Repeat the filtering pattern with a different question: Which third-class passengers were children?

# %%
third_class_children = titanic[
    (titanic["Pclass"] == 3) &
    (titanic["Age"] < 18)
]

third_class_children[["Name", "Age", "Sex", "Pclass", "Survived"]].head(10)
# Out:
#                                     Name   Age     Sex  Pclass  Survived
# 7         Palsson, Master. Gosta Leonard   2.0    male       3         0
# 10       Sandstrom, Miss. Marguerite Rut   4.0  female       3         1
# 14  Vestrom, Miss. Hulda Amanda Adolfina  14.0  female       3         0
# 16                  Rice, Master. Eugene   2.0    male       3         0
# 22           McGowan, Miss. Anna "Annie"  15.0  female       3         1
# 24         Palsson, Miss. Torborg Danira   8.0  female       3         0
# 39           Nicola-Yarred, Miss. Jamila  14.0  female       3         1
# 50            Panula, Master. Juha Niilo   7.0    male       3         0
# 59    Goodwin, Master. William Frederick  11.0    male       3         0
# 63                 Skoog, Master. Harald   4.0    male       3         0

# %%
# there is an alternative way to query using sql like syntax
also_third_class_children = titanic.query(
    "Pclass == 3 and Age < 18"
)

also_third_class_children[["Name", "Age", "Sex", "Pclass", "Survived"]].head(10)
# Out:
#                                     Name   Age     Sex  Pclass  Survived
# 7         Palsson, Master. Gosta Leonard   2.0    male       3         0
# 10       Sandstrom, Miss. Marguerite Rut   4.0  female       3         1
# 14  Vestrom, Miss. Hulda Amanda Adolfina  14.0  female       3         0
# 16                  Rice, Master. Eugene   2.0    male       3         0
# 22           McGowan, Miss. Anna "Annie"  15.0  female       3         1
# 24         Palsson, Miss. Torborg Danira   8.0  female       3         0
# 39           Nicola-Yarred, Miss. Jamila  14.0  female       3         1
# 50            Panula, Master. Juha Niilo   7.0    male       3         0
# 59    Goodwin, Master. William Frederick  11.0    male       3         0
# 63                 Skoog, Master. Harald   4.0    male       3         0

# %% [markdown]
# ### Check Your Understanding
#
# Read the code above and answer:
#
# - Which two columns are used for filtering?
# - What does `&` mean in this filter?
# - Why do we put each condition in parentheses?

# %% [markdown]
# ### Common Mistakes
#
# These are common and fixable:
#
# - writing `=` instead of `==` in a filter
# - forgetting quotation marks around a column name
# - misspelling a column name, such as `class` instead of `Pclass`
# - forgetting parentheses when combining filters

# %% [markdown]
# ### Independent Mini Task
#
# Create a filtered table for passengers who were at least 60 years old and paid a fare above 50.
#
# The working example is below. During class, try changing the age or fare threshold.

# %%
older_high_fare = titanic[
    (titanic["Age"] >= 60) &
    (titanic["Fare"] > 50)
]

older_high_fare[["Name", "Age", "Fare", "Pclass", "Survived"]].sort_values("Fare", ascending=False)
# Out:
#                                                  Name   Age      Fare  Pclass  \
# 438                                 Fortune, Mr. Mark  64.0  263.0000       1
# 829         Stone, Mrs. George Nelson (Martha Evelyn)  62.0   80.0000       1
# 587                  Frolicher-Stehli, Mr. Maxmillian  60.0   79.2000       1
# 275                 Andrews, Miss. Kornelia Theodosia  63.0   77.9583       1
# 366  Warren, Mrs. Frank Manley (Anna Sophia Atkinson)  60.0   75.2500       1
# 745                      Crosby, Capt. Edward Gifford  70.0   71.0000       1
# 54                     Ostby, Mr. Engelhart Cornelius  65.0   61.9792       1
#
#      Survived
# 438         0
# 829         1
# 587         1
# 275         1
# 366         1
# 745         0
# 54          0

# %% [markdown]
# ### Interpretation
#
# Filtering and sorting help us ask more focused questions. Before making broader conclusions, we still need to handle missing and inconvenient data carefully.

# %% [markdown]
# ## Subchapter 4: Cleaning Missing and Inconvenient Data
#
# ### Goal
#
# Learn basic cleaning decisions:
#
# - identify missing values
# - decide whether to fill, ignore, or exclude them
# - document the choice
#
# Cleaning is not just a technical step. It is part of the analysis.

# %% [markdown]
# ### Instructor Demonstration
#
# Start by checking missing values again.

# %%
missing_report = pd.DataFrame({
    "missing_rows": titanic.isna().sum(),
    "missing_percent": (titanic.isna().mean() * 100).round(1)
})

missing_report.sort_values("missing_rows", ascending=False)
# Out:
#                missing_rows  missing_percent
# Cabin                   687             77.1
# Age                     177             19.9
# Embarked                  2              0.2
# Survived                  0              0.0
# PassengerId               0              0.0
# Sex                       0              0.0
# Name                      0              0.0
# Pclass                    0              0.0
# SibSp                     0              0.0
# Ticket                    0              0.0
# Parch                     0              0.0
# Fare                      0              0.0
# embarked_city             0              0.0

# %% [markdown]
# For this beginner analysis, we will make three simple decisions:
#
# 1. Keep `Cabin` out of the main analysis because most values are missing.
# 2. Fill missing `Age` values with the median age in a new column called `Age_filled`.
# 3. Drop the few rows with missing `Embarked` values for summaries that use that column.
#
# We create a cleaned working copy instead of changing the original table.

# %%
titanic_clean = titanic.dropna(subset=["Embarked"]).copy()
# so titanic_clean will not have the Embarked with non value
# theis type of cleaning needs to be justified!

median_age = titanic_clean["Age"].median()
median_age
# Out:
# 28.0

# %%
# so we use so called median interpolation
# the big idea is that other values are useful and we do not want the missing age to distract
# I think we could do better we could infer better ranges
titanic_clean["Age_filled"] = titanic_clean["Age"].fillna(median_age)

titanic_clean[["Age", "Age_filled", "Embarked"]].head(10)
# Out:
#     Age  Age_filled Embarked
# 0  22.0        22.0        S
# 1  38.0        38.0        C
# 2  26.0        26.0        S
# 3  35.0        35.0        S
# 4  35.0        35.0        S
# 5   NaN        28.0        Q
# 6  54.0        54.0        S
# 7   2.0         2.0        S
# 8  27.0        27.0        S
# 9  14.0        14.0        C

# %% [markdown]
# Compare missing values before and after the cleaning step.

# %%
before_after_missing = pd.DataFrame({
    "original_missing": titanic.isna().sum(),
    "cleaned_missing": titanic_clean.isna().sum()
})

before_after_missing.sort_values("original_missing", ascending=False)
# Out:
#                original_missing  cleaned_missing
# Cabin                     687.0              687
# Age                       177.0              177
# Embarked                    2.0                0
# Fare                        0.0                0
# Name                        0.0                0
# Parch                       0.0                0
# PassengerId                 0.0                0
# Pclass                      0.0                0
# Sex                         0.0                0
# SibSp                       0.0                0
# Survived                    0.0                0
# Ticket                      0.0                0
# embarked_city               0.0                0
# Age_filled                  NaN                0

# %% [markdown]
# Notice that `Age` still has missing values, but `Age_filled` does not. This keeps both pieces of information:
#
# - the original `Age` column
# - a practical filled version for simple summaries

# %%
titanic_clean[["Age", "Age_filled"]].describe()
# Out:
#               Age  Age_filled
# count  712.000000  889.000000
# mean    29.642093   29.315152
# std     14.492933   12.984932
# min      0.420000    0.420000
# 25%     20.000000   22.000000
# 50%     28.000000   28.000000
# 75%     38.000000   35.000000
# max     80.000000   80.000000

# %% [markdown]
# ### Guided Practice
#
# Count `Embarked` again after removing the rows where it was missing.

# %%
titanic_clean["Embarked"].value_counts(dropna=False)
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %% [markdown]
# ### Check Your Understanding
#
# Answer in plain language:
#
# - Why did we create `Age_filled` instead of replacing `Age` directly?
# - Why is `Cabin` not a good main analysis column here?
# - What cleaning decision did we make for `Embarked`?

# %% [markdown]
# ### Common Mistake
#
# Missing values are not the same as zero.
#
# If age is missing, that does not mean the passenger was 0 years old. It means the age was not available in the dataset.

# %% [markdown]
# ### Independent Mini Task
#
# Inspect the cleaned data and write one sentence documenting the cleaning decision.
#
# Example sentence:
#
# `For this analysis, missing ages were filled with the median age in a separate column so the original age values remained available.`

# %%
titanic_clean.isna().sum()
# Out:
# PassengerId        0
# Survived           0
# Pclass             0
# Name               0
# Sex                0
# Age              177
# SibSp              0
# Parch              0
# Ticket             0
# Fare               0
# Cabin            687
# Embarked           0
# embarked_city      0
# Age_filled         0
# dtype: int64

# %% [markdown]
# ### Interpretation
#
# We now have a cleaned working table for the rest of the analysis. The cleaning choices are simple, visible, and documented.

# %% [markdown]
# ## Subtask 4b - Free Passengers
#
# Who were the passengers who paid nothing? They were not regular employees.

# %%
free_passangers = titanic_clean[titanic_clean["Fare"] == 0]

free_passangers[["Name", "Fare", "Pclass", "Age", "Sex", "Survived"]].head()
# Out:
#                                 Name  Fare  Pclass   Age   Sex  Survived
# 179              Leonard, Mr. Lionel   0.0       3  36.0  male         0
# 263            Harrison, Mr. William   0.0       1  40.0  male         0
# 271     Tornquist, Mr. William Henry   0.0       3  25.0  male         1
# 277      Parkes, Mr. Francis "Frank"   0.0       2   NaN  male         0
# 302  Johnson, Mr. William Cahoone Jr   0.0       3  19.0  male         0

# %%
# how many free passengers total?
print("Free passengers:", free_passangers.shape[0])
print("Total passengers:", titanic_clean.shape[0])
# Out:
# Free passengers: 15
# Total passengers: 889

# %%
# with one command let's see the main stats of our free_passengers
free_passangers.describe() # only the numerics
# Out:
#        PassengerId   Survived     Pclass        Age  SibSp  Parch  Fare  \
# count    15.000000  15.000000  15.000000   7.000000   15.0   15.0  15.0
# mean    516.400000   0.066667   1.933333  35.142857    0.0    0.0   0.0
# std     225.808958   0.258199   0.798809  10.023781    0.0    0.0   0.0
# min     180.000000   0.000000   1.000000  19.000000    0.0    0.0   0.0
# 25%     290.500000   0.000000   1.000000  30.500000    0.0    0.0   0.0
# 50%     482.000000   0.000000   2.000000  38.000000    0.0    0.0   0.0
# 75%     704.000000   0.000000   2.500000  39.500000    0.0    0.0   0.0
# max     823.000000   1.000000   3.000000  49.000000    0.0    0.0   0.0
#
#        Age_filled
# count   15.000000
# mean    31.333333
# std      7.527727
# min     19.000000
# 25%     28.000000
# 50%     28.000000
# 75%     37.000000
# max     49.000000

# %%
# let's plot our age distribution of free passengers
free_passangers['Age_filled'].plot(kind='hist', bins=10, title='Age Distribution of Free Passengers')
# so histogram shows distribution of some value
# Out:
# <Axes: title={'center': 'Age Distribution of Free Passengers'}, ylabel='Frequency'>

# %%
# how was distribution of ages in total?
titanic_clean['Age_filled'].plot(kind='hist', bins=20, title='Age Distribution of Total Passengers')
# so one minus of regular histograms is that number of bins affects visual display
# Out:
# <Axes: title={'center': 'Age Distribution of Total Passengers'}, ylabel='Frequency'>

# %%
# so let's plot age histogram with KDE
# we can use seaborn (more about seaborn tomorrow)
import seaborn as sns
sns.histplot(data=titanic_clean, x="Age_filled", kde=True)
# here bins are automatic and also KDE stays the same no matter the bins
# Kernel Density Estimator
# Out:
# <Axes: xlabel='Age_filled', ylabel='Count'>

# %%
# lets plot Men and Women KDE plots on the same figure
sns.histplot(data=titanic_clean, x="Age_filled", hue="Sex", kde=True)
#
# Out:
# <Axes: xlabel='Age_filled', ylabel='Count'>

# %%
titanic_clean.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked embarked_city  Age_filled
# 0      0         A/5 21171   7.2500   NaN        S   Southampton        22.0
# 1      0          PC 17599  71.2833   C85        C     Cherbourg        38.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S   Southampton        26.0
# ...

# %%
# let's plot fares and color hue by Pclass
sns.histplot(data=titanic_clean, x="Fare", hue="Pclass", kde=True)
#
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
# let's plot 1st and 2nd class only
sns.histplot(data=titanic_clean[titanic_clean["Pclass"] < 3], x="Fare", hue="Pclass", kde=True)
#
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %% [markdown]
# ### Interpration of 1st and 2nd class fares
#
# There were 2nd class passengers who paid more than 1st class passengers.

# %% [markdown]
# ## Subchapter 5: Grouping, Summarizing, and Mini Report Prep
#
# ### Goal
#
# Learn how to move from individual rows to summary tables.
#
# In Excel, this is similar to creating a Pivot Table. In Pandas, the main tools are `groupby()` and `pivot_table()`.

# %% [markdown]
# ### Instructor Demonstration
#
# First, calculate the overall survival rate. `Survived` is coded as:
#
# - `1` for survived
# - `0` for did not survive
#
# The mean of a 0/1 column is the share of rows with value 1.

# %%
# If we wish to stop here we could insert Assert False
# assert works by evaluating the expression after assert
# if True nothing happens and work continues
# if False it stops with optional message
assert 2*2==4, "Math is wrong!!" # This should work
# assert False, "Continue from here" # guranteed to stop here
print("This will never run unless above row is comment out...")
# Out:
# This will never run unless above row is comment out...

# %%
overall_survival_rate = titanic_clean["Survived"].mean()

round(overall_survival_rate, 3)
# Out:
# np.float64(0.382)

# %% [markdown]
# Now compare survival rates by passenger sex.

# %%
titanic_clean.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked embarked_city  Age_filled
# 0      0         A/5 21171   7.2500   NaN        S   Southampton        22.0
# 1      0          PC 17599  71.2833   C85        C     Cherbourg        38.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S   Southampton        26.0
# ...

# %%
# so we group by Sex column un calculate mean for survived column by gender
survival_by_sex = titanic_clean.groupby("Sex")["Survived"].mean().round(3).reset_index()

survival_by_sex
# Out:
#       Sex  Survived
# 0  female     0.740
# 1    male     0.189

# %% [markdown]
# Compare survival rates by passenger class.

# %%
survival_by_class = titanic_clean.groupby("Pclass")["Survived"].mean().round(3).reset_index()

survival_by_class
# Out:
#    Pclass  Survived
# 0       1     0.626
# 1       2     0.473
# 2       3     0.242

# %%
# let's group by Sex AND Pclass and calculate mean
survival_by_sex_and_class = titanic_clean.groupby(["Sex", "Pclass"])["Survived"].mean().round(3).reset_index()

survival_by_sex_and_class
# Out:
#       Sex  Pclass  Survived
# 0  female       1     0.967
# 1  female       2     0.921
# 2  female       3     0.500
# 3    male       1     0.369
# 4    male       2     0.157
# 5    male       3     0.135

# %%
# let's group by Sex and Pclass again but this time calculate mean for survived and also total count per grouping
survival_by_sex_and_class_count = titanic_clean.groupby(["Sex", "Pclass"])["Survived"].agg(["mean", "count"]).round(3).reset_index()

survival_by_sex_and_class_count
# Out:
#       Sex  Pclass   mean  count
# 0  female       1  0.967     92
# 1  female       2  0.921     76
# 2  female       3  0.500    144
# 3    male       1  0.369    122
# 4    male       2  0.157    108
# 5    male       3  0.135    347

# %% [markdown]
# Compare average fare by passenger class.

# %%
fare_by_class = titanic_clean.groupby("Pclass")["Fare"].mean().round(2).reset_index()

fare_by_class
# Out:
#    Pclass   Fare
# 0       1  84.19
# 1       2  20.66
# 2       3  13.68

# %% [markdown]
# We can summarize two grouping columns at the same time. This is close to a Pivot Table layout.

# %%
survival_pivot = pd.pivot_table(
    titanic_clean,
    values="Survived",
    index="Sex",
    columns="Pclass",
    aggfunc="mean" # so we take average of all Survived values for specific combination of Sex and Pclass

).round(3)

survival_pivot
# Out:
# Pclass      1      2      3
# Sex
# female  0.967  0.921  0.500
# male    0.369  0.157  0.135

# %% [markdown]
# A simple chart can make a summary easier to compare. Day 2 focuses more deeply on charts, but we can introduce one readable chart here.

# %%
plt.figure(figsize=(8, 5))

sns.barplot(data=survival_by_class, x="Pclass", y="Survived")

plt.title("Survival Rate Was Higher in First Class")
plt.xlabel("Passenger class")
plt.ylabel("Survival rate")
plt.ylim(0, 1)
plt.show()

# %% [markdown]
# ### Guided Practice
#
# Count passengers by both sex and passenger class.

# %%
passenger_counts = pd.crosstab(titanic_clean["Sex"], titanic_clean["Pclass"])

passenger_counts
# Out:
# Pclass    1    2    3
# Sex
# female   92   76  144
# male    122  108  347

# %%
embarked_survival = titanic_clean.groupby("Embarked")["Survived"].mean().round(3).reset_index()

embarked_survival
# Out:
#   Embarked  Survived
# 0        C     0.554
# 1        Q     0.390
# 2        S     0.337

# %%
titanic_clean.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'embarked_city',
#        'Age_filled'],
#       dtype='object')

# %%
# let's do the same grouping by embarked_city
embarked_survival_city = titanic_clean.groupby("embarked_city")["Survived"].mean().round(3).reset_index()

embarked_survival_city
# Out:
#   embarked_city  Survived
# 0     Cherbourg     0.554
# 1    Queenstown     0.390
# 2   Southampton     0.337

# %%
embarked_survival = titanic_clean.groupby("Embarked")["Survived"].mean().round(3).reset_index()
embarked_survival["survived_percentage"] = (embarked_survival["Survived"] * 100).round(1)
embarked_survival
# Out:
#   Embarked  Survived  survived_percentage
# 0        C     0.554                 55.4
# 1        Q     0.390                 39.0
# 2        S     0.337                 33.7

# %%
titanic_clean.groupby("embarked_city")["Survived"] # without agg function/s we have an unfinished object
# it is divided by column/s but nothing has been done to the results

# %%
# let's also add count for Survived
embarked_survival_city_count = titanic_clean.groupby("embarked_city")["Survived"].agg(["mean", "count"]).round(3).reset_index()

embarked_survival_city_count
# question why such differences?
# hypothesis - different cities had different proportions of passenger classes entering
# Out:
#   embarked_city   mean  count
# 0     Cherbourg  0.554    168
# 1    Queenstown  0.390     77
# 2   Southampton  0.337    644

# %% [markdown]
# ### Check Your Understanding
#
# Answer in plain language:
#
# - What does a survival rate of `0.742` mean?
# - Which passenger class had the highest survival rate in this dataset?
# - Why should we avoid saying that passenger class alone "caused" survival?
# - How is `groupby()` similar to a Pivot Table?

# %% [markdown]
# ### Common Mistake
#
# A grouped average is not a story by itself. It is evidence for a short interpretation.
#
# Good interpretation pattern:
#
# - observation: what the table shows
# - caution: what the table cannot prove
# - next question: what else we might inspect

# %% [markdown]
# ### Independent Mini Task
#
# Create one grouped summary using a column of your choice.
#
# The example below summarizes average fare by embarkation port.

# %%
fare_by_embarked = titanic_clean.groupby("Embarked")["Fare"].mean().round(2).reset_index()

fare_by_embarked
# Out:
#   Embarked   Fare
# 0        C  59.95
# 1        Q  13.28
# 2        S  27.08

# %% [markdown]
# ### Interpretation
#
# Grouped summaries help us compare categories. In this dataset, survival rates vary by sex and passenger class, and fares vary by passenger class and embarkation port. These are descriptive findings, not complete explanations.

# %% [markdown]
# ## End-of-Day Mini Report
#
# The final task is to assemble a short reproducible Titanic analysis.
#
# Your mini report should include:
#
# - one cleaning decision
# - two or more summary tables
# - one optional simple chart
# - 3 to 5 written conclusions
#
# The cells below provide a starting structure.

# %% [markdown]
# ### Cleaning Decision
#
# For this analysis, we kept the original `Age` column and created `Age_filled`, where missing ages were filled with the median age. We excluded rows with missing `Embarked` values because there were only a few of them. We did not use `Cabin` as a main analysis column because most values are missing.

# %%
report_missing_summary = pd.DataFrame({
    "original_missing": titanic.isna().sum(),
    "cleaned_missing": titanic_clean.isna().sum()
})

report_missing_summary.sort_values("original_missing", ascending=False)
# Out:
#                original_missing  cleaned_missing
# Cabin                     687.0              687
# Age                       177.0              177
# Embarked                    2.0                0
# Fare                        0.0                0
# Name                        0.0                0
# Parch                       0.0                0
# PassengerId                 0.0                0
# Pclass                      0.0                0
# Sex                         0.0                0
# SibSp                       0.0                0
# Survived                    0.0                0
# Ticket                      0.0                0
# embarked_city               0.0                0
# Age_filled                  NaN                0

# %% [markdown]
# ### Summary Table 1: Survival by Sex

# %%
survival_by_sex
# Out:
#       Sex  Survived
# 0  female     0.740
# 1    male     0.189

# %% [markdown]
# ### Summary Table 2: Survival by Passenger Class

# %%
survival_by_class
# Out:
#    Pclass  Survived
# 0       1     0.626
# 1       2     0.473
# 2       3     0.242

# %% [markdown]
# ### Summary Table 3: Average Fare by Passenger Class

# %%
fare_by_class
# Out:
#    Pclass   Fare
# 0       1  84.19
# 1       2  20.66
# 2       3  13.68

# %% [markdown]
# ### Optional Simple Chart

# %%
plt.figure(figsize=(7, 4))

sns.barplot(data=survival_by_sex, x="Sex", y="Survived")

plt.title("Survival Rate Was Higher for Female Passengers")
plt.xlabel("Passenger sex")
plt.ylabel("Survival rate")
plt.ylim(0, 1)
plt.show()

# %% [markdown]
# ### Short Conclusions
#
# Edit these conclusions in your own words:
#
# 1. In this dataset, female passengers had a higher survival rate than male passengers.
# 2. First-class passengers had a higher survival rate than second- and third-class passengers.
# 3. Average fare was higher for first-class passengers than for other passenger classes.
# 4. `Cabin` was not useful for the main analysis because most cabin values were missing.
# 5. These summaries describe patterns in the dataset, but they do not fully explain every individual outcome.

# %% [markdown]
# ## Common Mistakes and Troubleshooting
#
# - If you see `NameError`, a previous cell may not have been run. Run the setup and loading cells again.
# - If you see `KeyError`, check the exact column spelling with `titanic.columns`.
# - If a filter gives no rows, check the condition and whether the values are text or numbers.
# - Use `==` for comparison inside filters. A single `=` is for assigning a value to a variable.
# - Missing values are not zero. Treat them as unavailable information unless you have a clear reason to fill them.
# - If a chart looks strange, inspect the summary table behind it first.

# %% [markdown]
# ## Reflection
#
# Write short answers:
#
# - Which operation felt most similar to Excel?
# - Which step still feels confusing?
# - What part of this workflow could help in your work?
# - What would you want to practice again?
# - What did the data suggest, and what can it not prove?

# %% [markdown]
# ## Optional Bonus Tasks
#
# These tasks are optional. They are useful if you finish early.
#
# 1. Create a summary of survival rate by `Embarked`.
# 2. Create a summary of average `Age_filled` by `Pclass`.
# 3. Filter passengers whose fare was above 100 and inspect the result.
# 4. Create one extra bar chart from a grouped summary.
# 5. Write one new question you would ask about the Titanic data.

# %%
# embarked_survival["Survived"] = (embarked_survival["Survived"] * 100).round(2)
embarked_survival
# Out:
#   Embarked  Survived  survived_percentage
# 0        C     0.554                 55.4
# 1        Q     0.390                 39.0
# 2        S     0.337                 33.7

# %%
# i can save the results as csv or excel
embarked_survival.to_csv("embarked_survival.csv") # save on server
# download locally
from google.colab import files
files.download("embarked_survival.csv") # download
#
