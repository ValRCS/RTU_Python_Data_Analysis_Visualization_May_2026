# %% [markdown]
# # Basic Test for Notebook

# %%
print("This is a basic test for the notebook.")
# Out:
# This is a basic test for the notebook.

# %%
# what datetime and python version
from datetime import datetime
print(f"Current datetime: {datetime.now()}")
import sys
print(f"Python version: {sys.version}")
# where is the executable
print(f"Python executable: {sys.executable}")
# Out:
# Current datetime: 2026-05-10 20:41:25.703974
# Python version: 3.14.4 (tags/v3.14.4:23116f9, Apr  7 2026, 14:10:54) [MSC v.1944 64 bit (AMD64)]
# Python executable: d:\Github\RTU_Python_Data_Analysis_Visualization_May_2026\.venv\Scripts\python.exe

# %% [markdown]
# ## Checking for Pandas and related libraries
#
# We need to test whether our local environment has the necessary libraries installed to run our data analysis and visualization tasks. Let's start by checking for Pandas, NumPy, Matplotlib, and Seaborn.

# %%
# Checking for Pandas and related libraries
# We need to test whether our local environment has the necessary libraries installed to run our data analysis and visualization tasks. Let's start by checking for Pandas, NumPy, Matplotlib, and Seaborn.
try:
    import pandas as pd
    print(f"Current Pandas version: {pd.__version__}")
except ImportError as e:
    print(f"An error occurred while importing Pandas: {e}")
    print("Please install Pandas using 'pip install pandas' and try again.")

try:
    import numpy as np
    print(f"Current NumPy version: {np.__version__}")
except ImportError as e:
    print(f"An error occurred while importing NumPy: {e}")
    print("Please install NumPy using 'pip install numpy' and try again.")

try:
    import matplotlib.pyplot as plt
    from matplotlib import __version__ as mpl_version
    print("Matplotlib is installed successfully.")
    print(f"Current Matplotlib version: {mpl_version}")
except ImportError as e:
    print(f"An error occurred while importing Matplotlib: {e}")
    print("Please install Matplotlib using 'pip install matplotlib' and try again.")

try:
    import seaborn as sns
    print(f"Current Seaborn version: {sns.__version__}")
except ImportError as e:
    print(f"An error occurred while importing Seaborn: {e}")
    print("Please install Seaborn using 'pip install seaborn' and try again.")
#     import seaborn as sns
#     print("All libraries are installed and imported successfully.")
# except ImportError as e:
#     print(f"An error occurred while importing libraries: {e}")
# Out:
# Current Pandas version: 3.0.2
# Current NumPy version: 2.4.4
# Matplotlib is installed successfully.
# Current Matplotlib version: 3.10.9
# Current Seaborn version: 0.13.2

# %% [markdown]
# ## Checking helper libraries
#
# When working with pandas we need to have some helper libraries installed. Let's check for those as well. These include:
# - `openpyxl` for reading and writing Excel files
# - `requests` for making HTTP requests to fetch data from APIs
# - `beautifulsoup4` for parsing HTML and XML documents

# %%
# Checking for helper libraries
try:
    import openpyxl
    print(f"Current openpyxl version: {openpyxl.__version__}")
except ImportError as e:
    print(f"An error occurred while importing openpyxl: {e}")
    print("Please install openpyxl using 'pip install openpyxl' and try again.")

try:
    import requests
    print(f"Current requests version: {requests.__version__}")
except ImportError as e:
    print(f"An error occurred while importing requests: {e}")
    print("Please install requests using 'pip install requests' and try again.")

try:
    import bs4
    print(f"Current BeautifulSoup version: {bs4.__version__}")
except ImportError as e:
    print(f"An error occurred while importing BeautifulSoup: {e}")
    print("Please install BeautifulSoup using 'pip install beautifulsoup4' and try again.")
# Out:
# Current openpyxl version: 3.1.5
# Current requests version: 2.33.1
# Current BeautifulSoup version: 4.14.3
